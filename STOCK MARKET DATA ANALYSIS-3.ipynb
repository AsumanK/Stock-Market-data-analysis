# %% [markdown]
# # STOCK MARKET DATA ANALYSIS
# 1. Data Collection of four stock prices: BP.L, SSE.L, AV.L, and ULVR.L
# 2. Resampling of Data in terms of yearly, quarterly, monthly, and weekly
# 3. Moving averages of stock prices in terms of weekly, daily , etc.
# 4. Volatility of stocks

# %% [markdown]
# Reading csv files using Datareader module

# %%
pip install pandas_datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#import the necessary modules
import pandas_datareader as pdr
import datetime
import pandas as pd
import numpy as np

# %% [markdown]
# Read individual csv files of each stock market from yahoo using datareader

# %%
bpl = pdr.get_data_yahoo('BP.L', 
                          start=datetime.datetime(2005, 7, 5), 
                          end=datetime.datetime(2020, 8, 5))

# %%
ssel = pdr.get_data_yahoo('SSE.L',
                         start=datetime.datetime(2005, 7, 5),
                         end=datetime.datetime(2020, 8, 5))

# %%
avl = pdr.get_data_yahoo('AV.L',
                         start=datetime.datetime(2005, 7, 5),
                         end=datetime.datetime(2020, 8, 5))

# %%
ulvrl = pdr.get_data_yahoo('ULVR.L',
                         start=datetime.datetime(2005, 7, 5),
                         end=datetime.datetime(2020, 8, 5))

# %% [markdown]
# Lets view the data for each stock market

# %%
bpl.head(n=3)
# Out:
#                   High         Low   Open  Close       Volume   Adj Close
# Date
# 2005-07-05  623.150024  612.580017  614.5  622.5   87580588.0  272.018768
# 2005-07-06  637.200012  626.500000  627.0  630.0  103310632.0  275.296143
# 2005-07-07  628.000000  600.000000  626.0  621.5  120983616.0  271.581696

# %%
bpl.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
bpl.shape
# Out:
# (3802, 6)

# %%
bpl.index
# Out:
# DatetimeIndex(['2005-07-05', '2005-07-06', '2005-07-07', '2005-07-08',
#                '2005-07-11', '2005-07-12', '2005-07-13', '2005-07-14',
#                '2005-07-15', '2005-07-18',
#                ...
#                '2020-07-23', '2020-07-24', '2020-07-27', '2020-07-28',
#                '2020-07-29', '2020-07-30', '2020-07-31', '2020-08-03',
#                '2020-08-04', '2020-08-05'],
#               dtype='datetime64[ns]', name='Date', length=3802, freq=None)

# %%
avl.head(n=3)
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2005-07-05  576.512024  564.098999  576.512024  568.697021   9165498.0
# 2005-07-06  577.551025  566.857971  570.075989  574.672974  13365883.0
# 2005-07-07  578.810974  537.893982  574.672974  561.801025  18318509.0
#
#              Adj Close
# Date
# 2005-07-05  219.372253
# 2005-07-06  221.677399
# 2005-07-07  216.712204

# %%
avl.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
avl.shape
# Out:
# (3802, 6)

# %%
ulvrl.head(n=3)
# Out:
#                    High          Low         Open        Close      Volume  \
# Date
# 2005-07-05  1213.329956  1203.329956  1213.329956  1210.000000  11864885.0
# 2005-07-06  1218.890015  1207.780029  1213.329956  1213.329956   3669494.0
# 2005-07-07  1222.219971  1178.890015  1214.439941  1195.560059   6003735.0
#
#              Adj Close
# Date
# 2005-07-05  736.892944
# 2005-07-06  738.920837
# 2005-07-07  728.098633

# %%
ulvrl.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
ulvrl.shape
# Out:
# (3802, 6)

# %%
ssel.head(n=3)
# Out:
#                    High    Low    Open  Close     Volume   Adj Close
# Date
# 2005-07-05  1007.099976  978.0  1004.0  995.0  3814631.0  407.004852
# 2005-07-06  1005.000000  989.0   998.5  993.5  3616826.0  406.391144
# 2005-07-07  1000.000000  961.5  1000.0  984.5  5427195.0  402.709717

# %%
ssel.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
ssel.shape
# Out:
# (3802, 6)

# %% [markdown]
# The above outputs indicate the data was successfully loaded with date, high, low, open, close, volume and Adj close values and 3779 rows

# %% [markdown]
# Lets analyse the summary statistics of each stock market

# %%
bpl.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  3802.000000  3802.000000  3802.000000  3802.000000  3.802000e+03
# mean    498.018126   487.179860   492.881618   492.531647  4.574580e+07
# std      81.539624    82.592875    81.505975    81.549868  3.021986e+07
# min     249.800003     4.686000   226.899994   233.699997  0.000000e+00
# 25%     448.000000   439.750000   443.899994   443.750000  2.638270e+07
# 50%     488.899994   480.024994   484.675003   484.524994  3.588771e+07
# 75%     555.475006   545.500000   550.500000   549.850021  5.581801e+07
# max     723.000000   710.500000   713.500000   712.000000  3.597122e+08
#
#          Adj Close
# count  3802.000000
# mean    306.962181
# std      70.688653
# min     165.728973
# 25%     259.887245
# 50%     282.119141
# 75%     329.410019
# max     505.461426

# %% [markdown]
# The output shows 3779 stocks were traded within the specified time, with 497.2 as the highest mean price of stocks traded. Half of the stock price traded is 488.14 showing 723 as the maximum price of stock traded.

# %%
avl.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  3802.000000  3802.000000  3802.000000  3802.000000  3.802000e+03
# mean    470.911262   459.156363   465.423933   464.796645  1.107570e+07
# std     124.240459   124.395013   124.493027   124.318010  6.010819e+06
# min     165.598007   147.207993   151.621994   150.151001  0.000000e+00
# 25%     383.525002   371.274490   378.000000   377.681244  7.374282e+06
# 50%     452.000000   441.275497   446.750000   446.799988  9.771112e+06
# 75%     532.525497   523.445755   528.500000   528.000000  1.312593e+07
# max     816.955994   782.015991   787.531982   785.234009  9.504066e+07
#
#          Adj Close
# count  3802.000000
# mean    280.241398
# std      76.649563
# min      68.493637
# 25%     215.050606
# 50%     279.303619
# 75%     346.131317
# max     447.895660

# %% [markdown]
# The output shows 3779 stocks were traded within the specified time, with 470.2 as the highest mean price of stocks traded. Half of the stock price traded is 451 with 782 as the maximum price of stock traded.

# %%
ulvrl.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  3802.000000  3802.000000  3802.000000  3802.000000  3.802000e+03
# mean   2624.555003  2579.570276  2601.976265  2602.687814  3.504145e+06
# std    1108.333873  1092.563674  1100.083527  1100.657753  2.530841e+06
# min    1129.000000  1117.000000  1129.000000  1125.000000  0.000000e+00
# 25%    1683.000000  1647.250000  1666.250000  1665.000000  2.084525e+06
# 50%    2402.449951  2372.614990  2387.000000  2387.000000  2.778528e+06
# 75%    3527.125000  3469.750000  3493.375000  3502.250000  3.983361e+06
# max    5333.000000  5264.000000  5333.000000  5324.000000  3.000705e+07
#
#          Adj Close
# count  3802.000000
# mean   2163.060693
# std    1210.508143
# min     696.504883
# 25%    1092.391266
# 50%    1883.254639
# 75%    3079.625793
# max    5157.219238

# %% [markdown]
# The output shows 3779 stocks were traded within the specified time, with 2632.9 as the highest mean price of stocks traded. Half of the stock price traded is 2410 with 5333 as the maximum price of stock traded.

# %%
ssel.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  3802.000000  3802.000000  3802.000000  3802.000000  3.802000e+03
# mean   1352.401436  1326.324177  1339.818916  1339.270132  3.190467e+06
# std     175.832322   174.080252   175.100594   174.876609  1.966944e+06
# min     962.000000   946.000000   953.000000   955.000000  0.000000e+00
# 25%    1183.000000  1159.000000  1172.000000  1171.000000  1.986990e+06
# 50%    1378.250000  1352.000000  1366.000000  1364.000000  2.722734e+06
# 75%    1502.839996  1475.000000  1491.000000  1489.000000  3.828693e+06
# max    1858.000000  1675.239990  1691.000000  1696.000000  3.172203e+07
#
#          Adj Close
# count  3802.000000
# mean    851.498358
# std     252.035767
# min     390.642761
# 25%     637.383102
# 50%     861.641754
# 75%    1071.115295
# max    1620.339600

# %% [markdown]
# The output shows 3779 stocks were traded within the specified time, with 1354.64 as the highest mean price of stocks traded. Half of the stock price traded is 1381 with 1858 is the maximum price of stock traded.

# %% [markdown]
# # Visualisation of each stock market
# Since data is in time series format and a time series is a sequence of numerical data points taken at successive equally spaced points in time. In investing, a time series tracks the movement of stock price over a specified period of time.

# %%
#import the necessary modules 
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.dates as mdates

# %%
#visual plot of bpl
plt.plot(bpl.index, bpl['Adj Close'])
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.grid(True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The output shows an average stock price of 270 from mid 2005 to 2016 then sharply increased to 500in mid 2019, then declined sharply from the beginning of 2020 to 220 due to the pandemic then in mid 2020 moved slight up to 300.

# %%
#visual plot for avl
plt.plot(avl.index, avl['Adj Close'])
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.grid(True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The output shows the 2008 financial crisis hugely affected the stock price and the same effect experienced by a sharp fall due the covid 19 pandemic as showm from the early 2020.

# %%
#visual plot for ulvrl
plt.plot(ulvrl.index, ulvrl['Adj Close'])
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.grid(True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The output above shows a steady increase in the stock price from 600 in mid 2005 to 5200 in fall of 2019 and declined sharply since the pandemic to 3700 in february 2020 and gained to 4500 in fall 2020.

# %%
# visual plot for ssel
plt.plot(ssel.index, ssel['Adj Close'])
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.grid(True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The output shows that in mid 2005, the price steadly increased from 400 750 in 2008 then fell 450 by the end of 2008 then increased steadily to 1200 in late 2016 then fell to 850 in mid 2019 and sharply increased to 1600 in early 2020 followed a sharp decline to 1100 in feb-march then steadily gained to 1390 in fall of 2020.

# %%
#alternative to above are Subplots
f, ax = plt.subplots(2, 2, figsize=(10,10), sharex=True)
f.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
f.gca().xaxis.set_major_locator(mdates.YearLocator())

ax[0,0].plot(bpl.index, bpl['Adj Close'], color='r')
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('BP.L');

ax[0,1].plot(ulvrl.index, ulvrl['Adj Close'], color='g')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('ULVR.L');

ax[1,0].plot(avl.index, avl['Adj Close'], color='b')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('AV.L');

ax[1,1].plot(ssel.index, ssel['Adj Close'], color='y')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=90)
ax[1,1].set_title('SSE.L');

# %% [markdown]
# # Resampling
# This involves changing the frequncy of your time series observations
# 1. Down-sampling
# This involves decreasing the frequency of the samples such annual into monthly.
# 2. Up-sampling
# This involves increasing the frequency of the samples such as hours to minutes.
#
# In this case, we will look at 2019, 7, 5 to 2020, 8, 5 for all stocks.

# %% [markdown]
# # One year resampling

# %%
# up-sampling for bpl
bpl_20 = bpl.loc[pd.Timestamp('2019-07-05'):pd.Timestamp('2020-08-05')]
plt.plot(bpl_20.index, bpl_20['Adj Close'])
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The price dropped sharply from february to the lowest price of 220 in mid march where it increased steadily.

# %%
ulvrl_20 = ulvrl.loc[pd.Timestamp('2019-07-05'):pd.Timestamp('2020-08-05')]
plt.plot(ulvrl_20.index, ulvrl_20['Adj Close'])
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The output shows a sharp decline especially in mid march of 2020 then increased steadily.

# %%
avl_20 = avl.loc[pd.Timestamp('2019-07-05'):pd.Timestamp('2020-08-05')]
plt.plot(avl_20.index, avl_20['Adj Close'])
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# From mid febraury, the price dropped sharply until mid march where it increased steadily.

# %%
ssel_20 = ssel.loc[pd.Timestamp('2019-07-05'):pd.Timestamp('2020-08-05')]
plt.plot(ssel_20.index, ssel_20['Adj Close'])
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The price increased sharply untill mid february where a sharfp decline was experienced in  april then it increased steadily.

# %% [markdown]
# # Quarterly resampling

# %%
#for bpl
monthly_bpl_20 = bpl_20.resample('4M').mean()
plt.plot(monthly_bpl_20.index, monthly_bpl_20['Adj Close'])
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
#for ulvrl
monthly_ulvrl_20 = ulvrl_20.resample('4M').mean()
plt.plot(monthly_ulvrl_20.index, monthly_ulvrl_20['Adj Close'])
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
# for avl
monthly_avl_20 = avl_20.resample('4M').mean()
plt.plot(monthly_avl_20.index, monthly_avl_20['Adj Close'])
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
#for ssel
monthly_ssel_20 = ssel_20.resample('4M').mean()
plt.plot(monthly_ssel_20.index, monthly_ssel_20['Adj Close'])
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Weekly resampling

# %% [markdown]
# We need to load weekily datasets for the four stock markets

# %%
#for bpl
bpl_20 = bpl.loc[pd.Timestamp('2019-07-05'):pd.Timestamp('2020-08-05')]

# %%
weekly_bpl_20 = bpl_20.resample('W').mean()
weekly_bpl_20.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2019-07-07  548.599976  541.400024  545.200012  542.500000  29516996.0
# 2019-07-14  549.359998  543.940002  547.020007  545.960010  23398164.2
# 2019-07-21  534.779980  527.659998  532.919995  529.419995  37967293.0
# 2019-07-28  528.700012  521.379993  525.199988  524.079993  40068525.4
# 2019-08-04  542.500000  531.123401  539.979993  536.300012  47647926.4
#
#              Adj Close
# Date
# 2019-07-07  477.912323
# 2019-07-14  480.960437
# 2019-07-21  466.389642
# 2019-07-28  461.685364
# 2019-08-04  472.450507

# %%
#data for ulvrl
ulvrl_20 = ulvrl.loc[pd.Timestamp('2019-07-05'):pd.Timestamp('2020-08-05')]
weekly_ulvrl_20 = ulvrl_20.resample('W').mean()

# %%
#data for avl
avl_20 = avl.loc[pd.Timestamp('2019-07-05'):pd.Timestamp('2020-08-05')]
weekly_avl_20 = avl_20.resample('W').mean()

# %%
#data for ssel
ssel_20 = ssel.loc[pd.Timestamp('2019-07-05'):pd.Timestamp('2020-08-05')]
weekly_ssel_20 = ssel_20.resample('W').mean()

# %%
#visual for bpl
plt.plot(weekly_bpl_20.index, weekly_bpl_20['Adj Close'], '-o')
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
#visual for ulvrl
plt.plot(weekly_ulvrl_20.index, weekly_ulvrl_20['Adj Close'], '-o')
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
#visual for avl
plt.plot(weekly_avl_20.index, weekly_avl_20['Adj Close'], '-o')
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
#visual for ssel
plt.plot(weekly_ssel_20.index, weekly_ssel_20['Adj Close'], '-o')
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Analysing the difference between Levels (Resampling Weekly)

# %%
#for bpl
bpl['diff'] = bpl['Open'] - bpl['Close']
bpl_diff = bpl.resample('W').mean()
bpl_diff.head(5)
# Out:
#                   High         Low     Open    Close      Volume   Adj Close  \
# Date
# 2005-07-10  632.587509  615.395004  623.875  628.875  95367645.0  274.804474
# 2005-07-17  631.010400  620.443201  625.600  623.800  93215598.4  272.586768
# 2005-07-24  631.659607  617.911987  624.200  624.300  87697547.6  272.805304
# 2005-07-31  639.342004  627.916003  634.300  632.400  75169698.2  276.344843
# 2005-08-07  639.900000  631.380005  634.100  636.300  57161796.6  278.049072
#
#             diff
# Date
# 2005-07-10  -5.0
# 2005-07-17   1.8
# 2005-07-24  -0.1
# 2005-07-31   1.9
# 2005-08-07  -2.2

# %%
ulvrl['diff'] = ulvrl['Open'] - ulvrl['Close']
ulvrl_diff = ulvrl.resample('W').mean()

# %%
avl['diff'] = avl['Open'] - avl['Close']
avl_diff = avl.resample('W').mean()

# %%
ssel['diff'] = ssel['Open'] - ssel['Close']
ssel_diff = ssel.resample('W').mean()

# %%
#visual for bpl
plt.plot(bpl_diff.loc['2019-07-05':'2020-08-05'].index, bpl_diff.loc['2019-07-05':'2020-08-05']['diff'])
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
#visual for ulvrl
plt.plot(ulvrl_diff.loc['2019-07-05':'2020-08-05'].index, ulvrl_diff.loc['2019-07-05':'2020-08-05']['diff'])
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
#visual for avl
plt.plot(avl_diff.loc['2019-07-05':'2020-08-05'].index, avl_diff.loc['2019-07-05':'2020-08-05']['diff'])
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
#visual for ssel
plt.plot(ssel_diff.loc['2019-07-05':'2020-08-05'].index, ssel_diff.loc['2019-07-05':'2020-08-05']['diff'])
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The output above show a similar result (sharp fall) between mid march and beginning of appril

# %% [markdown]
# # Moving Windows within each stock market
# Moving windows exists when you compute the statistics on a window of data represented by a specific period of time and then slide the window across the data by the specified time. That way, the statistic is continually calculated as long as the window falls first within the dates of time series.
#
# The rolling mean smoothens out short-term fluctuations and highlights longer-term trends in data.

# %% [markdown]
# # Daily percentages

# %%
daily_close_bpl = bpl[['Adj Close']]

# Daily returns
daily_pct_change_bpl = daily_close_bpl.pct_change()

# Replace NA values with 0
daily_pct_change_bpl.fillna(0, inplace=True)

daily_pct_change_bpl.head()
# Out:
#             Adj Close
# Date
# 2005-07-05   0.000000
# 2005-07-06   0.012048
# 2005-07-07  -0.013493
# 2005-07-08   0.032180
# 2005-07-11  -0.011691

# %%
#data for ulvrl
daily_close_ulvrl = bpl[['Adj Close']]

# Daily returns
daily_pct_change_ulvrl = daily_close_ulvrl.pct_change()

# Replace NA values with 0
daily_pct_change_ulvrl.fillna(0, inplace=True)

daily_pct_change_ulvrl.head()
# Out:
#             Adj Close
# Date
# 2005-07-05   0.000000
# 2005-07-06   0.012048
# 2005-07-07  -0.013493
# 2005-07-08   0.032180
# 2005-07-11  -0.011691

# %%
#data for avl
daily_close_avl = avl[['Adj Close']]

# Daily returns
daily_pct_change_avl = daily_close_avl.pct_change()

# Replace NA values with 0
daily_pct_change_avl.fillna(0, inplace=True)

daily_pct_change_avl.head()
# Out:
#             Adj Close
# Date
# 2005-07-05   0.000000
# 2005-07-06   0.010508
# 2005-07-07  -0.022398
# 2005-07-08   0.011456
# 2005-07-11   0.015372

# %%
#data for ssel
daily_close_ssel = ssel[['Adj Close']]

# Daily returns
daily_pct_change_ssel = daily_close_ssel.pct_change()

# Replace NA values with 0
daily_pct_change_ssel.fillna(0, inplace=True)

daily_pct_change_ssel.head()
# Out:
#             Adj Close
# Date
# 2005-07-05   0.000000
# 2005-07-06  -0.001508
# 2005-07-07  -0.009059
# 2005-07-08   0.006603
# 2005-07-11   0.000000

# %% [markdown]
# Visual representation of each stock using histograms

# %%
import seaborn as sns
sns.set()

# %%
# Set up the matplotlib figure
f, axes = plt.subplots(2, 2, figsize=(14, 8))

# Plot a simple histogram with binsize determined automatically
sns.distplot(daily_pct_change_bpl['Adj Close'], color="b", ax=axes[0, 0], axlabel='BP.L');

# Plot a kernel density estimate and rug plot
sns.distplot(daily_pct_change_ulvrl['Adj Close'], color="r", ax=axes[0, 1], axlabel='ULVR.L');

# Plot a filled kernel density estimate
sns.distplot(daily_pct_change_avl['Adj Close'], color="g", ax=axes[1, 0], axlabel='AV.L');

# Plot a historgram and kernel density estimate
sns.distplot(daily_pct_change_ssel['Adj Close'], color="m", ax=axes[1, 1], axlabel='SSE.L');

# %% [markdown]
# BP.L output shows that price fell to -0.39 but also price went up to 0.26 meaning that a small amount of profit was made.
#
# ULVR.L output shows that price fell to almost -0.39 but also price went up to 0.25 implying a profit was made.
#
# AV.L output shows that price fell to -0.43 but also also price went up to 0.27 implying a loss was made.
#
# SSE.L output shows that price fell to -0.24 but also price went up to 0.15 meaning a small profit was made.

# %% [markdown]
# # Volatility of stocks
#
# The volatility of a stock is the measurement of change in variance of a stock over a specified period of time.
#
# The aim of comparing the volatility of a stock with another stock is to find out which stock is less riskier or comparing to the market index is to find out which stock is less riskier in the overall market.
#
# The higher the volatility, the riskier the investment in that stock.

# %%
#for bpl
min_periods = 75 

# Calculate the volatility
vol = daily_pct_change_bpl.rolling(min_periods).std() * np.sqrt(min_periods) 

vol.fillna(0,inplace=True)

vol.tail()
# Out:
#             Adj Close
# Date
# 2020-07-30   0.267881
# 2020-07-31   0.265906
# 2020-08-03   0.258276
# 2020-08-04   0.264759
# 2020-08-05   0.262988

# %%
# Plot the volatility
vol.plot(figsize=(10, 8))

# Show the plot
plt.show()

# %% [markdown]
# Ouput shows the stock was very volatile at specific periods in 2009 to 2019, then 2011, a period after the 2008 financial crisis and very volatile during the pandemic (covid 19).

# %%
#for ulvrl
min_periods = 75 

# Calculate the volatility
vol1 = daily_pct_change_ulvrl.rolling(min_periods).std() * np.sqrt(min_periods) 

vol1.fillna(0,inplace=True)

vol1.tail()
# Out:
#             Adj Close
# Date
# 2020-07-30   0.267881
# 2020-07-31   0.265906
# 2020-08-03   0.258276
# 2020-08-04   0.264759
# 2020-08-05   0.262988

# %% [markdown]
# ULVR.L output shows its less volatile

# %%
# Plot the volatility
vol1.plot(figsize=(10, 8))

# Show the plot
plt.show()

# %%
#for avl
min_periods = 75 

# Calculate the volatility
vol2 = daily_pct_change_avl.rolling(min_periods).std() * np.sqrt(min_periods) 

vol2.fillna(0,inplace=True)

vol2.tail()
# Out:
#             Adj Close
# Date
# 2020-07-30   0.260383
# 2020-07-31   0.258456
# 2020-08-03   0.255378
# 2020-08-04   0.255462
# 2020-08-05   0.254888

# %% [markdown]
# AV.L stock shows its less volatile.

# %%
# Plot the volatility
vol1.plot(figsize=(10, 8))

# Show the plot
plt.show()

# %%
#for ssel
min_periods = 75 

# Calculate the volatility
vol2 = daily_pct_change_ssel.rolling(min_periods).std() * np.sqrt(min_periods) 

vol2.fillna(0,inplace=True)

vol2.tail()
# Out:
#             Adj Close
# Date
# 2020-07-30   0.192277
# 2020-07-31   0.191283
# 2020-08-03   0.190740
# 2020-08-04   0.190760
# 2020-08-05   0.190472

# %% [markdown]
# Output shows SSE.L is less volatile.

# %%
# Plot the volatility
vol2.plot(figsize=(10, 8))

# Show the plot
plt.show()

# %% [markdown]
# Similar trends were experienced with the rest of the stocks with impacts felt during the 2008 and 2020 covid pandemic

# %% [markdown]
# # Rolling Means (Trends and Seasonality)
# Instead of variance, the stocks show us short and long term windows

# %%
bpl_adj_close_px = bpl['Adj Close']
# Short moving window rolling mean (monthly)
bpl['42'] = bpl_adj_close_px.rolling(window=40).mean()

# Long moving window rolling mean (yearly)
bpl['252'] = bpl_adj_close_px.rolling(window=252).mean()

# Plot the adjusted closing price, the short and long windows of rolling means
bpl[['Adj Close', '42', '252']].plot(title="BP.L")

# Show plot
plt.show()

ulvrl_adj_close_px = ulvrl['Adj Close']
# Short moving window rolling mean
ulvrl['42'] = ulvrl_adj_close_px.rolling(window=40).mean()

# Long moving window rolling mean
ulvrl['252'] = ulvrl_adj_close_px.rolling(window=252).mean()

# Plot the adjusted closing price, the short and long windows of rolling means
ulvrl[['Adj Close', '42', '252']].plot(title="ULVR.L")

# Show plot
plt.show()

avl_adj_close_px = avl['Adj Close']
# Short moving window rolling mean
avl['42'] = avl_adj_close_px.rolling(window=40).mean()

# Long moving window rolling mean
avl['252'] = avl_adj_close_px.rolling(window=252).mean()

# Plot the adjusted closing price, the short and long windows of rolling means
avl[['Adj Close', '42', '252']].plot(title="AV.L")

# Show plot
plt.show()

ssel_adj_close_px = ssel['Adj Close']
# Short moving window rolling mean
ssel['42'] = ssel_adj_close_px.rolling(window=40).mean()

# Long moving window rolling mean
ssel['252'] = ssel_adj_close_px.rolling(window=252).mean()

# Plot the adjusted closing price, the short and long windows of rolling means
ssel[['Adj Close', '42', '252']].plot(title="SSE.L")

# Show plot
plt.show()

# %% [markdown]
# Outputs indicate the adj close, short term (trends) and long term (seasonality), however, its better to invest in long term when its stable compared to short term when its more volatile.

# %% [markdown]
# Analysing one year

# %%
#for bpl
bpl.loc['2019-07-05':'2020-08-05'][['Adj Close', '42', '252']].plot(title="BP.L in 2020");

# %% [markdown]
# The output shows stable movements  from 2019 to 2020-03 where it falls sharply to the lowest price in terms of short term but the for long term, its a steady decline.

# %%
#for ulvrl
ulvrl.loc['2019-07-05':'2020-08-05'][['Adj Close', '42', '252']].plot(title="ULVR.L in 2020");

# %% [markdown]
# The output shows a short term steady decline from 2019-09 to 2020-03 where it falls sharply to the lowest price then increased steadily while the long term shows a small steady decline from 2020-03 until now.

# %%
#for avl
avl.loc['2019-07-05':'2020-08-05'][['Adj Close', '42', '252']].plot(title="AV.L in 2020");

# %% [markdown]
# Output shows a stable movement in both short and long term however from 2020-03, a sharp decline is experienced for a short term then it increased steadily from 2020-04 unlike the long term which is still declining steadily.

# %%
# for ssel
ssel.loc['2019-07-05':'2020-08-05'][['Adj Close', '42', '252']].plot(title="SSE.L in 2020");

# %% [markdown]
# Output shows a steady increase in price for both short and long term to 2020-02 then fell sharply until 2020-04 where it increased steadily.

# %% [markdown]
# In conclusion, all stocks showed steadiness, however, the 2008 financial crisis and the early 2020 covid 29 pandemic have shown the negative impact on stock prices. However, out of the four stocks, SSE.L is the most stable and profitable if invested in.
